# %% [markdown]
# ## Env Setup & Test Runs

# %%
!~/miniconda3/bin/conda --version
# Out:
# conda 23.10.0

# %%
!~/miniconda3/bin/conda env create -f environment.yml
# Out:
# Channels:
#  - pytorch
#  - conda-forge
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ...
# libjpeg-turbo-2.1.4  | 988 KB    |                                       |   0%
# zstd-1.5.2           | 448 KB    |                                       |   0%
#
# brotli-bin-1.0.9     | 19 KB     |                                       |   0%
#
#
# brotli-1.0.9         | 18 KB     |                                       |   0%
#
#
#
# libev-4.33           | 104 KB    |                                       |   0%
#
#
#
#
# decorator-5.1.1      | 12 KB     |                                       |   0%
#
#
#
#
#
# ptyprocess-0.7.0     | 17 KB     |                                       |   0%
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    |                                       |   0%
#
#
#
#
#
#
#
# freeglut-3.2.2       | 162 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# hdf5-1.12.2          | 3.5 MB    |                                       |   0%
# ...

# %%
!~/miniconda3/bin/conda list envs
# Out:
# # packages in environment at /root/miniconda3:
# #
# # Name                    Version                   Build  Channel

# %%
!~/miniconda3/bin/conda activate ffcv

# %%
# !source activate ffcv

# %%
# !python -u main_imp.py --data ./data --dataset $data --arch $arch --prune_type rewind_lt --rewind_epoch 8 --save_dir ${save_dir} --rate ${rate} --pruning_times 2 --num_workers 8
# !python -u /notebooks/Unlearn-Sparse/main_imp.py --data ./data --dataset TinyImagenet --arch resnet18 --prune_type rewind_lt --rewind_epoch 8 --save_dir /notebooks/Unlearn-Sparse/save_dir --rate 3 --pruning_times 2 --num_workers 1

# %%
# cifar100
# !python -u /notebooks/Unlearn-Sparse/main_imp.py --data ./data --dataset cifar100 --arch resnet18 --prune_type rewind_lt --rewind_epoch 8 --save_dir /notebooks/Unlearn-Sparse/save_dir --rate 3 --pruning_times 2 --num_workers 1
# cifar10
# !python -u /notebooks/Unlearn-Sparse/main_imp.py --data ./data --dataset cifar10 --arch resnet18 --prune_type rewind_lt --rewind_epoch 8 --save_dir /notebooks/Unlearn-Sparse/save_dir_cifar10 --rate 3 --pruning_times 2 --num_workers 1

# %%
python -u /notebooks/Unlearn-Sparse/main_imp.py --data ./data --dataset cifar10 --arch resnet18 --prune_type rewind_lt --rewind_epoch 8 --save_dir /notebooks/Unlearn-Sparse/save_dir_cifar10 --rate 0.5 --pruning_times 1 --num_workers 1

# %%
python -u /notebooks/Unlearn-Sparse/main_imp.py --data ./data --dataset cifar10 --arch resnet18 --prune_type rewind_lt --rewind_epoch 8 --save_dir /notebooks/Unlearn-Sparse/save_dir_cifar10_nov30 --rate 0.95 --pruning_times 2 --num_workers 1 --epochs 20

# %% [markdown]
# L1 sparse:

# %%
# python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_L1sparse --mask ${mask_path} --unlearn FT_prune --num_indexes_to_replace 4500 --alpha ${alpha} --unlearn_lr 0.01 --unlearn_epochs 10
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_L1sparse --mask /notebooks/Unlearn-Sparse/save_dir_cifar10/0model_SA_best.pth.tar --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 2 --class_to_replace 2

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_L1sparse_2 --mask /notebooks/Unlearn-Sparse/save_dir_cifar10/0checkpoint.pth.tar --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 2 --class_to_replace 2

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_L1sparse_2 --mask /notebooks/Unlearn-Sparse/save_dir_cifar10/0model_SA_best.pth.tar --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 2 --class_to_replace 2

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_FT_nov30 --mask /notebooks/Unlearn-Sparse/save_dir_cifar10_nov30/1model_SA_best.pth.tar --unlearn FT --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 2 --class_to_replace 2

# %% [markdown]
# ### Dec 1

# %% [markdown]
# First, running a cmd to save a resnet18 model (unpruned) to a checkpoint:

# %%
python -u /notebooks/Unlearn-Sparse/train_blank.py --data ./data --dataset cifar10 --arch resnet18 --prune_type rewind_lt --rewind_epoch 8 --save_dir /notebooks/Unlearn-Sparse/save_dir_cifar10_unpruned --rate 0.5 --pruning_times 1 --num_workers 1 --epochs 2

# %% [markdown]
# Done. Now unlearning on that:

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_FT_dec1_unpruned --mask /notebooks/Unlearn-Sparse/save_dir_cifar10_unpruned/resnet18_trained.pth.tar --unlearn FT --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 2

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_FT_nov30 --mask /notebooks/Unlearn-Sparse/save_dir_cifar10_nov30/1model_SA_best.pth.tar --unlearn FT --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 2 --class_to_replace 2

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_cifar10_dec2_FT --mask /notebooks/Unlearn-Sparse/save_dir_cifar10_nov30/1model_SA_best.pth.tar --unlearn FT --alpha 0.2 --unlearn_lr 0.01 
--unlearn_epochs 2 --class_to_replace 2

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_cifar10_dec2_FT_prune 
--mask /notebooks/Unlearn-Sparse/save_dir_cifar10_nov30/1model_SA_best.pth.tar --unlearn FT --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 2 --class_to_replace 2

# %% [markdown]
# ## Experiments

# %% [markdown]
# Save trained CIFAR-10 resnet:

# %%
python -u /notebooks/Unlearn-Sparse/train_blank.py --data ./data --dataset cifar10 --arch resnet18 --prune_type rewind_lt --rewind_epoch 8 --save_dir $modelsavedir --rate 0.5 --pruning_times 1 --num_workers 1 --epochs 2
#add a directory to save the model to

# %% [markdown]
# Use this model, run unlearning algo on it, to get results for the standard CIFAR10 dataset:

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir2 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 2
#savedir named according to class that is unlearned

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir3 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 3

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir4 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 4

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir5 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 5

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir6 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 6

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir7 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 7

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir8 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 8

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir9 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 9

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir $unlearned_model_save_dir10 --mask $modelsavedir --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 10

# %% [markdown]
# Dec 2

# %%
python -u /notebooks/Unlearn-Sparse/main_forget.py --save_dir /notebooks/Unlearn-Sparse/save_dir_FTprune_dec2 --mask /notebooks/Unlearn-Sparse/save_dir_cifar10_unpruned/resnet18_trained.pth.tar --unlearn FT_prune --alpha 0.2 --unlearn_lr 0.01 --unlearn_epochs 10 --class_to_replace 2 --data custom
